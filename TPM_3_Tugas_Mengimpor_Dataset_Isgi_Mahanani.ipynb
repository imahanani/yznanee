# %% [markdown]
# <a href="https://colab.research.google.com/github/imahanani/yznanee/blob/main/TPM_3_Tugas_Mengimpor_Dataset_Isgi_Mahanani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas : Mengimport dataset .csv pada Bahasa Pemrograman Python

# %%
#Memastikan data .csv yang baru saja diIMPORT terbaca oleh Notebook
import pandas as pd #import library
df = pd.read_csv("Assessment R & Python_ Dataset_superstore_simple.csv") #'df' adalah nama variable, bisa diubah sesuai preferensi
df #menampilkan variable df
# Out:
#             order_id  order_date customer_id    segment         category  \
# 0     CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1     CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2     CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3     US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4     US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
# ...              ...         ...         ...        ...              ...
# 9983  CA-2014-110422  2014-01-21    TB-21400   Consumer        Furniture
# 9984  CA-2017-121258  2017-02-26    DB-13060   Consumer        Furniture
# 9985  CA-2017-121258  2017-02-26    DB-13060   Consumer       Technology
# 9986  CA-2017-121258  2017-02-26    DB-13060   Consumer  Office Supplies
# 9987  CA-2017-119914  2017-05-04    CC-12220   Consumer  Office Supplies
#
#      sub_category     sales  quantity    profit
# ...

# %%
#Ringkasan statistikal
df.describe()
# Out:
#              sales     quantity       profit
# count  9988.000000  9988.000000  9988.000000
# mean    221.952598     3.789147    27.105341
# std     514.818043     2.225586   186.115016
# min       0.444000     1.000000 -3839.990400
# 25%      17.248000     2.000000     1.730250
# 50%      54.376000     3.000000     8.652800
# 75%     209.814000     5.000000    29.345400
# max    9892.740000    14.000000  4946.370000
